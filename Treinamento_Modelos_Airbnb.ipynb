# %%
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/basetreinamento.csv')

# %%
def avaliar_modelo(nome_modelo, y_teste, previsão):
    r2 = r2_score(y_teste, previsão)
    RMSE = np.sqrt(mean_squared_error(y_teste, previsão))
    return f'Modelo{nome_modelo}:\nR²:{r2}\nRMSE:{RMSE}'

# %%
modelo_rf = RandomForestRegressor()
modelo_lr = LinearRegression()
modelo_et = ExtraTreesRegressor()
'''modelos = {'RandomForest' : modelo_rf,
           'LinearRegression': modelo_lr,
           'ExtraTrees': modelo_et}
y = df['price']
X = df.drop('price', axis=1)'''
# Out:
# "modelos = {'RandomForest' : modelo_rf,\n           'LinearRegression': modelo_lr,\n           'ExtraTrees': modelo_et}\ny = df['price']\nX = df.drop('price', axis=1)"

# %%
'''X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

for nome_modelo, modelo in modelos.items():
  modelo.fit(X_train, y_train)
  previsão = modelo.predict(X_test)
  print(avaliar_modelo(nome_modelo, y_test, previsão))'''
# Out:
# 'X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)\n\nfor nome_modelo, modelo in modelos.items():\n  modelo.fit(X_train, y_train)\n  previsão = modelo.predict(X_test)\n  print(avaliar_modelo(nome_modelo, y_test, previsão))'

# %%
'''importancia = pd.DataFrame(modelo_et.feature_importances_, X_train.columns)
importancia = importancia.sort_values(by=0, ascending=False)
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=importancia.index, y=importancia[0])
ax.set_xlabel('Características')
ax.set_ylabel('Importância')
ax.set_title('Importância das Características')
ax.tick_params(axis='x', rotation=90)
plt.show()'''
# Out:
# "importancia = pd.DataFrame(modelo_et.feature_importances_, X_train.columns)\nimportancia = importancia.sort_values(by=0, ascending=False)\nplt.figure(figsize=(10, 6))\nax = sns.barplot(x=importancia.index, y=importancia[0])\nax.set_xlabel('Características')\nax.set_ylabel('Importância')\nax.set_title('Importância das Características')\nax.tick_params(axis='x', rotation=90)\nplt.show()"

# %%
df = df.drop('is_business_travel_ready', axis=1)

# %%
y = df['price']
X = df.drop('price', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
modelo_et.fit(X_train, y_train)
previsão = modelo_et.predict(X_test)
print(avaliar_modelo('ExtraTrees', y_test, previsão))
# Out:
# ModeloExtraTrees:
# R²:0.9733031570963785
# RMSE:43.15484291981647

# %%
X['property_type_Apartment']
X.to_csv('basetreinamento.csv', index=False)

# %%
import joblib

# %%
joblib.dump(modelo_et, 'modelo_et.pkl')
# Out:
# ['modelo_et.pkl']

# %%
from google.colab import files
files.download('modelo_et.pkl')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import joblib
# O parâmetro compress varia de 0 a 9 (3 é o equilíbrio ideal)
joblib.dump(modelo_et, '/content/drive/MyDrive/modelo_et.pkl', compress=3)
# Out:
# ['/content/drive/MyDrive/modelo_et.pkl']
